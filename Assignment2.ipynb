# %%
import pandas as pd
import numpy as np
from scipy.stats import multivariate_normal
from random import choices
from collections import Counter

# %%
def largest(num1, num2, num3):
    if (num1 > num2) and (num1 > num3):
        largest_num = 1
    elif (num2 > num1) and (num2 > num3):
        largest_num = 2
    else:
        largest_num = 3
    return largest_num


def BayesClassification(sample_n, act_miu1, act_miu2, act_sigma1, act_sigma2, act_prior1, act_prior2):
    random_seed=1000
    dist1=multivariate_normal(cov = act_sigma1, mean = act_miu1, seed = random_seed)
    dist2=multivariate_normal(cov = act_sigma2, mean = act_miu2, seed = random_seed)
    # Generate a series of 1s & 2s with above probability. It will be used to invoke the sampling function
    x=choices(population=[1,2], weights=[act_prior1,act_prior2], k=sample_n)
    y=Counter(x)
    half1=int(y[1]/2)
    half2=int(y[2]/2)
    print("First Distribution Estimate: ")
    print("Prior=> ",act_prior1)
    print("Mean=> ", act_miu1)
    print("Cov Matrix=>", act_sigma1)
    print("Second Distribution Estimate:")
    print( "Prior=> ",act_prior2 )
    print("Mean=> ", act_miu2)
    print("Cov Matrix=>", act_sigma2)
    # Sampling from the distribution of the FIRST class
    data1 = dist2.rvs(size = y[1])
    data1_train=data1[:half1]
    data1_test=data1[half1:]
    
    # Sampling from the distribution of the SECOND class
    data2 = dist1.rvs(size = y[2])
    data2_train=data2[:half2]
    data2_test=data2[half2:]
    
    print("Sample For First Distribution: ")
    print(data1[:10])
    print("Sample For Second Distribution: ")
    print(data2[:10])
    print("Training Data Geerated")
    
    # Get the total number of data for train
    total_train_records=len(data1_train)+len(data2_train)
    
    # Estimate the values of mean and cov matrices
    miu1_hat=np.mean(data1_train,0)
    sigma1_hat=np.cov(data1_train,rowvar=False)
    miu2_hat=np.mean(data2_train,0)
    sigma2_hat=np.cov(data2_train,rowvar=False)
    
    # Estimate the prior probability
    prior1_hat=len(data1_train)/total_train_records
    prior2_hat=len(data2_train)/total_train_records
    
    print("First Distribution Estimate:")
    print("Prior=> ",prior1_hat)
    print("Mean=> ", miu1_hat)
    print("Cov Matrix=>", sigma1_hat)

    print("Second Distribution Estimate:")
    print( "Prior=> ",prior2_hat )
    print("Mean=> ", miu2_hat)
    print("Cov Matrix=>", sigma2_hat)
    
    #Actual class data
    actual1=np.repeat(1,len(data1_test))
    actual2=np.repeat(2,len(data2_test))
    actual_classes=np.concatenate((actual1,actual2), axis=0)
    
    # Concatinate the data that is coming from both the classes for final classification
    final_test_data=np.concatenate((data1_test,data2_test), axis=0)
    
    # ESTIMATED the mis-classification rate
    # Calculate the components of the posteriori probability
    denom1=multivariate_normal.pdf(final_test_data, mean=miu1_hat, cov=sigma1_hat)*prior1_hat
    denom2=multivariate_normal.pdf(final_test_data, mean=miu2_hat, cov=sigma2_hat)*prior2_hat
    denominatior=denom1+denom2
    
    # Conpute the posteriori probability for both the classes
    class1_prob=denom1/denominatior
    class2_prob=denom2/denominatior
    
    class_prob_diff=class1_prob-class2_prob
    predicted_classes=[1 if x>0 else 2 for x in class_prob_diff]
    classification_diff=actual_classes-predicted_classes    
    estimated_mis_class_rate=len([1 for x in classification_diff if x!=0])/len(actual_classes)
    #estimated_mis_class_rate
    print("Misclassification Rate for ESTIMATED Parameters: ",estimated_mis_class_rate)
    
    # ACTUAL the mis-classification rate
    # Calculate the components of the posteriori probability
    denom1=multivariate_normal.pdf(final_test_data, mean=miu1, cov=sigma1)*act_prior1
    denom2=multivariate_normal.pdf(final_test_data, mean=miu2, cov=sigma2)*act_prior2
    denominatior=denom1+denom2
    
    # Conpute the posteriori probability for both the classes
    class1_prob=denom1/denominatior
    class2_prob=denom2/denominatior
    
    class_prob_diff=class1_prob-class2_prob
    predicted_classes=[1 if x>0 else 2 for x in class_prob_diff]
    classification_diff=actual_classes-predicted_classes    
    actual_mis_class_rate=len([1 for x in classification_diff if x!=0])/len(actual_classes)
    
    print("Misclassification Rate for ACTUAL Parameters: ",actual_mis_class_rate)
    
    return(actual_mis_class_rate-estimated_mis_class_rate)


def BayesClassificationTHREE(sample_n, act_miu1, act_miu2, act_miu3, act_sigma1, act_sigma2, act_sigma3, act_prior1, act_prior2, act_prior3):
    random_seed=1000
    dist1=multivariate_normal(cov = act_sigma1, mean = act_miu1, seed = random_seed)
    dist2=multivariate_normal(cov = act_sigma2, mean = act_miu2, seed = random_seed)
    dist3=multivariate_normal(cov = act_sigma3, mean = act_miu3, seed = random_seed)
    # Generate a series of 1s & 2s with above probability. It will be used to invoke the sampling function
    x=choices(population=[1,2,3], weights=[act_prior1,act_prior2,act_prior3], k=sample_n)
    y=Counter(x)
    half1=int(y[1]/2)
    half2=int(y[2]/2)
    half3=int(y[3]/2)
    print("First Distribution Estimate: ")
    print("Prior=> ",act_prior1)
    print("Mean=> ", act_miu1)
    print("Cov Matrix=>", act_sigma1)
    print("Second Distribution Estimate:")
    print( "Prior=> ",act_prior2 )
    print("Mean=> ", act_miu2)
    print("Cov Matrix=>", act_sigma2)
    print("Third Distribution Estimate:")
    print( "Prior=> ",act_prior3 )
    print("Mean=> ", act_miu3)
    print("Cov Matrix=>", act_sigma3)

    # Sampling from the distribution of the FIRST class
    data1 = dist1.rvs(size = y[1])
    data1_train=data1[:half1]
    data1_test=data1[half1:]
    
    # Sampling from the distribution of the SECOND class
    data2 = dist2.rvs(size = y[2])
    data2_train=data2[:half2]
    data2_test=data2[half2:]
    
    # Sampling from the distribution of the THIRD class
    data3 = dist3.rvs(size = y[3])
    data3_train=data3[:half3]
    data3_test=data3[half3:]

    
    print("Sample For First Distribution: ")
    print(data1[:10])
    print("Sample For Second Distribution: ")
    print(data2[:10])
    print("Sample For Third Distribution: ")
    print(data3[:10])

    print("Training Data Geerated")
    
    # Get the total number of data for train
    total_train_records=len(data1_train)+len(data2_train)+len(data3_train)
    
    # Estimate the values of mean and cov matrices
    miu1_hat=np.mean(data1_train,0)
    sigma1_hat=np.cov(data1_train,rowvar=False)
    miu2_hat=np.mean(data2_train,0)
    sigma2_hat=np.cov(data2_train,rowvar=False)
    miu3_hat=np.mean(data3_train,0)
    sigma3_hat=np.cov(data3_train,rowvar=False)

    
    # Estimate the prior probability
    prior1_hat=len(data1_train)/total_train_records
    prior2_hat=len(data2_train)/total_train_records
    prior3_hat=len(data3_train)/total_train_records
    
    print("First Distribution Estimate:")
    print("Prior=> ",prior1_hat)
    print("Mean=> ", miu1_hat)
    print("Cov Matrix=>", sigma1_hat)

    print("Second Distribution Estimate:")
    print( "Prior=> ",prior2_hat )
    print("Mean=> ", miu2_hat)
    print("Cov Matrix=>", sigma2_hat)
    
    print("Second Distribution Estimate:")
    print( "Prior=> ",prior3_hat)
    print("Mean=> ", miu3_hat)
    print("Cov Matrix=>", sigma3_hat)

    
    #Actual class data
    actual1=np.repeat(1,len(data1_test))
    actual2=np.repeat(2,len(data2_test))
    actual3=np.repeat(3,len(data3_test))
    actual_classes=np.concatenate((actual1,actual2,actual3), axis=0)
    
    # Concatinate the data that is coming from both the classes for final classification
    final_test_data=np.concatenate((data1_test,data2_test,data3_test), axis=0)
    
    # ESTIMATED the mis-classification rate
    # Calculate the components of the posteriori probability
    denom1=multivariate_normal.pdf(final_test_data, mean=miu1_hat, cov=sigma1_hat)*prior1_hat
    denom2=multivariate_normal.pdf(final_test_data, mean=miu2_hat, cov=sigma2_hat)*prior2_hat
    denom3=multivariate_normal.pdf(final_test_data, mean=miu3_hat, cov=sigma3_hat)*prior3_hat
    denominatior=denom1+denom2+denom3
    
    # Conpute the posteriori probability for both the classes
    class1_prob=denom1/denominatior
    class2_prob=denom2/denominatior
    class3_prob=denom3/denominatior
        
    #predicted_classes=largest(class1_prob,class2_prob,class3_prob)
    #print(predicted_classes)
    predicted_classes=np.repeat(0,len(class1_prob))
    for i in range(len(class1_prob)):
        predicted_classes[i]=largest(class1_prob[i],class2_prob[i],class3_prob[i])
    
    classification_diff=actual_classes-predicted_classes    
    estimated_mis_class_rate=len([1 for x in classification_diff if x!=0])/len(actual_classes)
    #estimated_mis_class_rate
    print("Misclassification Rate for ESTIMATED Parameters: ",estimated_mis_class_rate)
    
    # ACTUAL the mis-classification rate
    # Calculate the components of the posteriori probability
    denom1=multivariate_normal.pdf(final_test_data, mean=miu1, cov=sigma1)*act_prior1
    denom2=multivariate_normal.pdf(final_test_data, mean=miu2, cov=sigma2)*act_prior2
    denom3=multivariate_normal.pdf(final_test_data, mean=miu3, cov=sigma3)*act_prior3
    denominatior=denom1+denom2+denom3
    
    # Conpute the posteriori probability for both the classes
    class1_prob=denom1/denominatior
    class2_prob=denom2/denominatior
    class3_prob=denom3/denominatior
    
    predicted_classes=np.repeat(0,len(class1_prob))
    for i in range(len(class1_prob)):
        predicted_classes[i]=largest(class1_prob[i],class2_prob[i],class3_prob[i])

    
    #class_prob_diff=class1_prob-class2_prob
    #predicted_classes=[1 if x>0 else 2 for x in class_prob_diff]
    classification_diff=actual_classes-predicted_classes    
    actual_mis_class_rate=len([1 for x in classification_diff if x!=0])/len(actual_classes)
    
    print("Misclassification Rate for ACTUAL Parameters: ",actual_mis_class_rate)
    
    return(actual_mis_class_rate-estimated_mis_class_rate)

# %%
miu1=np.array([0,0])
sigma1=np.array([[1, 0], [0, 1]])

miu2=np.array([0,1])
sigma2=np.array([[1, -0.5], [-0.5, 2]])

miu3=np.array([-1,0.5])
sigma3=np.array([[0.75, 0.2], [0.2, 0.8]])

miu4=np.array([-2,1.3])
sigma4=np.array([[2, 0.8], [0.8, 1.6]])

# %%
#Case 1
misclass_rate_diff_n2000=BayesClassification(2000,miu1,miu2,sigma1,sigma2,0.75,0.25)
misclass_rate_diff_n5000=BayesClassification(5000,miu1,miu2,sigma1,sigma2,0.75,0.25)
misclass_rate_diff_n10000=BayesClassification(10000,miu1,miu2,sigma1,sigma2,0.75,0.25)
misclass_rate_diff_n20000=BayesClassification(20000,miu1,miu2,sigma1,sigma2,0.75,0.25)

print("Misclass Rate when N=2000: ",misclass_rate_diff_n2000)
print("Misclass Rate when N=5000: ",misclass_rate_diff_n5000)
print("Misclass Rate when N=10000: ",misclass_rate_diff_n10000)
print("Misclass Rate when N=20000: ",misclass_rate_diff_n20000)
# Out:
# First Distribution Estimate:
# Prior=>  0.75
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.25
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.7477477477477478
# Mean=>  [-0.01187862  0.99177593]
# Cov Matrix=> [[ 0.99318339 -0.47934372]
#  [-0.47934372  2.05780579]]
# Second Distribution Estimate:
# Prior=>  0.25225225225225223
# Mean=>  [-0.04999151 -0.00462939]
# Cov Matrix=> [[0.96761453 0.03743314]
#  [0.03743314 1.05268462]]
# Misclassification Rate for ESTIMATED Parameters:  0.24175824175824176
# Misclassification Rate for ACTUAL Parameters:  0.45254745254745254
# First Distribution Estimate:
# Prior=>  0.75
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.25
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.7531012404961985
# Mean=>  [-0.02937623  0.99841412]
# Cov Matrix=> [[ 1.03909141 -0.53138394]
#  [-0.53138394  2.03581475]]
# Second Distribution Estimate:
# Prior=>  0.24689875950380152
# Mean=>  [ 0.01151176 -0.00297217]
# Cov Matrix=> [[1.00909955 0.04061553]
#  [0.04061553 0.99094134]]
# Misclassification Rate for ESTIMATED Parameters:  0.23950419832067174
# Misclassification Rate for ACTUAL Parameters:  0.4566173530587765
# First Distribution Estimate:
# Prior=>  0.75
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.25
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.749749949989998
# Mean=>  [0.00435553 0.98870986]
# Cov Matrix=> [[ 1.04821979 -0.51525442]
#  [-0.51525442  2.01464829]]
# Second Distribution Estimate:
# Prior=>  0.250250050010002
# Mean=>  [ 0.00226575 -0.00804642]
# Cov Matrix=> [[1.04276127 0.0059551 ]
#  [0.0059551  1.02640517]]
# Misclassification Rate for ESTIMATED Parameters:  0.23795240951809637
# Misclassification Rate for ACTUAL Parameters:  0.45250949810037994
# First Distribution Estimate:
# Prior=>  0.75
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.25
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.7496749674967497
# Mean=>  [-0.00269916  0.97869399]
# Cov Matrix=> [[ 1.03203453 -0.50184877]
#  [-0.50184877  1.98930633]]
# Second Distribution Estimate:
# Prior=>  0.25032503250325033
# Mean=>  [-0.00067849 -0.02238595]
# Cov Matrix=> [[ 1.01463785 -0.02319656]
#  [-0.02319656  1.02363295]]
# Misclassification Rate for ESTIMATED Parameters:  0.23427657234276572
# Misclassification Rate for ACTUAL Parameters:  0.45395460453954606
# Misclass Rate when N=2000:  0.21078921078921078
# Misclass Rate when N=5000:  0.21711315473810475
# Misclass Rate when N=10000:  0.21455708858228356
# Misclass Rate when N=20000:  0.21967803219678034

# %%
#Case 2
misclass_rate_diff_n2000=BayesClassification(2000,miu1,miu2,sigma1,sigma2,0.5,0.5)
misclass_rate_diff_n5000=BayesClassification(5000,miu1,miu2,sigma1,sigma2,0.5,0.5)
misclass_rate_diff_n10000=BayesClassification(10000,miu1,miu2,sigma1,sigma2,0.5,0.5)
misclass_rate_diff_n20000=BayesClassification(20000,miu1,miu2,sigma1,sigma2,0.5,0.5)

print("Misclass Rate when N=2000: ",misclass_rate_diff_n2000)
print("Misclass Rate when N=5000: ",misclass_rate_diff_n5000)
print("Misclass Rate when N=10000: ",misclass_rate_diff_n10000)
print("Misclass Rate when N=20000: ",misclass_rate_diff_n20000)
# Out:
# First Distribution Estimate:
# Prior=>  0.5
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.5
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.502
# Mean=>  [0.00747941 0.97421647]
# Cov Matrix=> [[ 0.97689311 -0.485003  ]
#  [-0.485003    2.03104203]]
# Second Distribution Estimate:
# Prior=>  0.498
# Mean=>  [-0.02121226 -0.00071313]
# Cov Matrix=> [[1.01015216 0.02359908]
#  [0.02359908 0.99946903]]
# Misclassification Rate for ESTIMATED Parameters:  0.328
# Misclassification Rate for ACTUAL Parameters:  0.668
# First Distribution Estimate:
# Prior=>  0.5
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.5
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.4973989595838335
# Mean=>  [-0.00744206  0.99822921]
# Cov Matrix=> [[ 1.02450303 -0.52068597]
#  [-0.52068597  2.08998184]]
# Second Distribution Estimate:
# Prior=>  0.5026010404161665
# Mean=>  [ 0.00105893 -0.00621879]
# Cov Matrix=> [[1.04097815 0.00643649]
#  [0.00643649 1.02417005]]
# Misclassification Rate for ESTIMATED Parameters:  0.3270691723310676
# Misclassification Rate for ACTUAL Parameters:  0.6733306677329068
# First Distribution Estimate:
# Prior=>  0.5
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.5
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.4960992198439688
# Mean=>  [-0.01745611  0.99052197]
# Cov Matrix=> [[ 1.04330099 -0.52480288]
#  [-0.52480288  2.00852021]]
# Second Distribution Estimate:
# Prior=>  0.5039007801560312
# Mean=>  [ 0.00085609 -0.01960458]
# Cov Matrix=> [[ 1.01511977 -0.02272837]
#  [-0.02272837  1.02632478]]
# Misclassification Rate for ESTIMATED Parameters:  0.33313337332533494
# Misclassification Rate for ACTUAL Parameters:  0.6684663067386523
# First Distribution Estimate:
# Prior=>  0.5
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.5
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.49844984498449846
# Mean=>  [0.00694954 0.97200284]
# Cov Matrix=> [[ 1.03235987 -0.51089311]
#  [-0.51089311  2.00785316]]
# Second Distribution Estimate:
# Prior=>  0.5015501550155016
# Mean=>  [-0.01841424 -0.00520678]
# Cov Matrix=> [[ 1.00807908 -0.01051322]
#  [-0.01051322  1.02714202]]
# Misclassification Rate for ESTIMATED Parameters:  0.3244675532446755
# Misclassification Rate for ACTUAL Parameters:  0.6762323767623237
# Misclass Rate when N=2000:  0.34
# Misclass Rate when N=5000:  0.34626149540183926
# Misclass Rate when N=10000:  0.3353329334133173
# Misclass Rate when N=20000:  0.3517648235176482

# %%
#Case 3
misclass_rate_diff_n2000=BayesClassification(2000,miu1,miu2,sigma1,sigma2,0.6,0.4)
misclass_rate_diff_n5000=BayesClassification(5000,miu1,miu2,sigma1,sigma2,0.6,0.4)
misclass_rate_diff_n10000=BayesClassification(10000,miu1,miu2,sigma1,sigma2,0.6,0.4)
misclass_rate_diff_n20000=BayesClassification(20000,miu1,miu2,sigma1,sigma2,0.6,0.4)

print("Misclass Rate when N=2000: ",misclass_rate_diff_n2000)
print("Misclass Rate when N=5000: ",misclass_rate_diff_n5000)
print("Misclass Rate when N=10000: ",misclass_rate_diff_n10000)
print("Misclass Rate when N=20000: ",misclass_rate_diff_n20000)
# Out:
# First Distribution Estimate:
# Prior=>  0.6
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.4
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.5865865865865866
# Mean=>  [-0.0159357   1.02102247]
# Cov Matrix=> [[ 0.96220397 -0.47043395]
#  [-0.47043395  2.05229202]]
# Second Distribution Estimate:
# Prior=>  0.4134134134134134
# Mean=>  [-0.04377246  0.00349762]
# Cov Matrix=> [[1.05611737 0.01936816]
#  [0.01936816 0.98190174]]
# Misclassification Rate for ESTIMATED Parameters:  0.33966033966033965
# Misclassification Rate for ACTUAL Parameters:  0.6253746253746254
# First Distribution Estimate:
# Prior=>  0.6
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.4
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.5984
# Mean=>  [-0.01297857  0.96773513]
# Cov Matrix=> [[ 1.02837685 -0.50819585]
#  [-0.50819585  2.03376005]]
# Second Distribution Estimate:
# Prior=>  0.4016
# Mean=>  [-0.00357826 -0.00909196]
# Cov Matrix=> [[1.05693822 0.00921887]
#  [0.00921887 1.01959047]]
# Misclassification Rate for ESTIMATED Parameters:  0.3084
# Misclassification Rate for ACTUAL Parameters:  0.6292
# First Distribution Estimate:
# Prior=>  0.6
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.4
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.6006
# Mean=>  [-0.00881348  0.98880255]
# Cov Matrix=> [[ 1.05446383 -0.52165936]
#  [-0.52165936  2.01762256]]
# Second Distribution Estimate:
# Prior=>  0.3994
# Mean=>  [ 0.00567987 -0.03691399]
# Cov Matrix=> [[ 1.02398782 -0.02165694]
#  [-0.02165694  1.02330373]]
# Misclassification Rate for ESTIMATED Parameters:  0.3332
# Misclassification Rate for ACTUAL Parameters:  0.598
# First Distribution Estimate:
# Prior=>  0.6
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.4
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.5991
# Mean=>  [0.00514668 0.96480319]
# Cov Matrix=> [[ 1.03962532 -0.50516878]
#  [-0.50516878  1.98446916]]
# Second Distribution Estimate:
# Prior=>  0.4009
# Mean=>  [-0.01139782  0.00099352]
# Cov Matrix=> [[ 1.01099851 -0.01992508]
#  [-0.01992508  1.04325007]]
# Misclassification Rate for ESTIMATED Parameters:  0.321
# Misclassification Rate for ACTUAL Parameters:  0.6151
# Misclass Rate when N=2000:  0.28571428571428575
# Misclass Rate when N=5000:  0.3208
# Misclass Rate when N=10000:  0.2648
# Misclass Rate when N=20000:  0.2941

# %%
#Case 4
misclass_rate_diff_n2000=BayesClassification(2000,miu1,miu3,sigma1,sigma3,0.7,0.3)
misclass_rate_diff_n5000=BayesClassification(5000,miu1,miu3,sigma1,sigma3,0.7,0.3)
misclass_rate_diff_n10000=BayesClassification(10000,miu1,miu3,sigma1,sigma3,0.7,0.3)
misclass_rate_diff_n20000=BayesClassification(20000,miu1,miu3,sigma1,sigma3,0.7,0.3)

print("Misclass Rate when N=2000: ",misclass_rate_diff_n2000)
print("Misclass Rate when N=5000: ",misclass_rate_diff_n5000)
print("Misclass Rate when N=10000: ",misclass_rate_diff_n10000)
print("Misclass Rate when N=20000: ",misclass_rate_diff_n20000)
# Out:
# First Distribution Estimate:
# Prior=>  0.7
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.3
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.702
# Mean=>  [-0.99169431  0.49440528]
# Cov Matrix=> [[0.76544537 0.20326764]
#  [0.20326764 0.77376446]]
# Second Distribution Estimate:
# Prior=>  0.298
# Mean=>  [-0.01355731  0.00388174]
# Cov Matrix=> [[1.02094365 0.06559417]
#  [0.06559417 1.01765967]]
# Misclassification Rate for ESTIMATED Parameters:  0.203
# Misclassification Rate for ACTUAL Parameters:  0.376
# First Distribution Estimate:
# Prior=>  0.7
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.3
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.7096
# Mean=>  [-0.98180606  0.49194912]
# Cov Matrix=> [[0.7509972  0.20471347]
#  [0.20471347 0.82845083]]
# Second Distribution Estimate:
# Prior=>  0.2904
# Mean=>  [-0.00863455 -0.01246998]
# Cov Matrix=> [[1.00632092 0.02192471]
#  [0.02192471 1.00145896]]
# Misclassification Rate for ESTIMATED Parameters:  0.1952
# Misclassification Rate for ACTUAL Parameters:  0.3688
# First Distribution Estimate:
# Prior=>  0.7
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.3
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.7115423084616923
# Mean=>  [-0.99720432  0.50469262]
# Cov Matrix=> [[0.76079016 0.19796432]
#  [0.19796432 0.82614374]]
# Second Distribution Estimate:
# Prior=>  0.28845769153830764
# Mean=>  [-0.01612556 -0.01658451]
# Cov Matrix=> [[1.02721708 0.00135848]
#  [0.00135848 1.02556255]]
# Misclassification Rate for ESTIMATED Parameters:  0.1957608478304339
# Misclassification Rate for ACTUAL Parameters:  0.3613277344531094
# First Distribution Estimate:
# Prior=>  0.7
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.3
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Second Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.701070107010701
# Mean=>  [-0.9848675   0.50769226]
# Cov Matrix=> [[0.74599287 0.18960282]
#  [0.18960282 0.82398272]]
# Second Distribution Estimate:
# Prior=>  0.29892989298929895
# Mean=>  [-0.00351836 -0.01444538]
# Cov Matrix=> [[ 1.01920696 -0.02031323]
#  [-0.02031323  1.0434813 ]]
# Misclassification Rate for ESTIMATED Parameters:  0.20237976202379762
# Misclassification Rate for ACTUAL Parameters:  0.3661633836616338
# Misclass Rate when N=2000:  0.173
# Misclass Rate when N=5000:  0.1736
# Misclass Rate when N=10000:  0.1655668866226755
# Misclass Rate when N=20000:  0.1637836216378362

# %%
#Case 5
misclass_rate_diff_n2000=BayesClassification(2000,miu2,miu3,sigma2,sigma3,0.3,0.7)
misclass_rate_diff_n5000=BayesClassification(5000,miu2,miu3,sigma2,sigma3,0.3,0.7)
misclass_rate_diff_n10000=BayesClassification(10000,miu2,miu3,sigma2,sigma3,0.3,0.7)
misclass_rate_diff_n20000=BayesClassification(20000,miu2,miu3,sigma2,sigma3,0.3,0.7)

print("Misclass Rate when N=2000: ",misclass_rate_diff_n2000)
print("Misclass Rate when N=5000: ",misclass_rate_diff_n5000)
print("Misclass Rate when N=10000: ",misclass_rate_diff_n10000)
print("Misclass Rate when N=20000: ",misclass_rate_diff_n20000)
# Out:
# First Distribution Estimate:
# Prior=>  0.3
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Second Distribution Estimate:
# Prior=>  0.7
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Second Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.2982982982982983
# Mean=>  [-0.9933372   0.51198914]
# Cov Matrix=> [[0.81335649 0.21121144]
#  [0.21121144 0.76722299]]
# Second Distribution Estimate:
# Prior=>  0.7017017017017017
# Mean=>  [-0.00954631  0.99312246]
# Cov Matrix=> [[ 0.96614161 -0.47328526]
#  [-0.47328526  2.01861759]]
# Misclassification Rate for ESTIMATED Parameters:  0.2007992007992008
# Misclassification Rate for ACTUAL Parameters:  0.24775224775224775
# First Distribution Estimate:
# Prior=>  0.3
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Second Distribution Estimate:
# Prior=>  0.7
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Second Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.3016
# Mean=>  [-0.98711532  0.49390052]
# Cov Matrix=> [[0.78095972 0.2034966 ]
#  [0.2034966  0.79636385]]
# Second Distribution Estimate:
# Prior=>  0.6984
# Mean=>  [-0.01946381  0.97772676]
# Cov Matrix=> [[ 1.04291985 -0.53320005]
#  [-0.53320005  2.01090726]]
# Misclassification Rate for ESTIMATED Parameters:  0.2072
# Misclassification Rate for ACTUAL Parameters:  0.2492
# First Distribution Estimate:
# Prior=>  0.3
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Second Distribution Estimate:
# Prior=>  0.7
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Second Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.3014
# Mean=>  [-0.97303444  0.49689869]
# Cov Matrix=> [[0.76550821 0.20222533]
#  [0.20222533 0.82327485]]
# Second Distribution Estimate:
# Prior=>  0.6986
# Mean=>  [0.00529823 0.98535433]
# Cov Matrix=> [[ 1.04141984 -0.5133865 ]
#  [-0.5133865   2.02518422]]
# Misclassification Rate for ESTIMATED Parameters:  0.2124
# Misclassification Rate for ACTUAL Parameters:  0.2478
# First Distribution Estimate:
# Prior=>  0.3
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Second Distribution Estimate:
# Prior=>  0.7
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Second Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.297029702970297
# Mean=>  [-0.98844735  0.49582957]
# Cov Matrix=> [[0.75664674 0.1937254 ]
#  [0.1937254  0.8346826 ]]
# Second Distribution Estimate:
# Prior=>  0.7029702970297029
# Mean=>  [0.00243533 0.97486465]
# Cov Matrix=> [[ 1.04041772 -0.51054633]
#  [-0.51054633  1.98930638]]
# Misclassification Rate for ESTIMATED Parameters:  0.20727927207279273
# Misclassification Rate for ACTUAL Parameters:  0.25307469253074694
# Misclass Rate when N=2000:  0.046953046953046945
# Misclass Rate when N=5000:  0.04200000000000001
# Misclass Rate when N=10000:  0.03539999999999999
# Misclass Rate when N=20000:  0.045795420457954206

# %%
#Case 6
misclass_rate_diff_n2000=BayesClassificationTHREE(2000,miu1,miu2,miu3,sigma1,sigma2,sigma3,0.3,0.4,0.3)
misclass_rate_diff_n5000=BayesClassificationTHREE(5000,miu1,miu2,miu3,sigma1,sigma2,sigma3,0.3,0.4,0.3)
misclass_rate_diff_n10000=BayesClassificationTHREE(10000,miu1,miu2,miu3,sigma1,sigma2,sigma3,0.3,0.4,0.3)
misclass_rate_diff_n20000=BayesClassificationTHREE(20000,miu1,miu2,miu3,sigma1,sigma2,sigma3,0.3,0.4,0.3)

print("Misclass Rate when N=2000: ",misclass_rate_diff_n2000)
print("Misclass Rate when N=5000: ",misclass_rate_diff_n5000)
print("Misclass Rate when N=10000: ",misclass_rate_diff_n10000)
print("Misclass Rate when N=20000: ",misclass_rate_diff_n20000)
# Out:
# First Distribution Estimate:
# Prior=>  0.3
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.4
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Third Distribution Estimate:
# Prior=>  0.3
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Sample For Second Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Third Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.2902902902902903
# Mean=>  [-0.01951261 -0.00953286]
# Cov Matrix=> [[1.03802463 0.0544215 ]
#  [0.0544215  1.02546204]]
# Second Distribution Estimate:
# Prior=>  0.4074074074074074
# Mean=>  [0.02561872 0.94054131]
# Cov Matrix=> [[ 0.98854442 -0.52634131]
#  [-0.52634131  2.13346473]]
# Second Distribution Estimate:
# Prior=>  0.3023023023023023
# Mean=>  [-0.99563954  0.5072239 ]
# Cov Matrix=> [[0.8081634  0.21323489]
#  [0.21323489 0.76273126]]
# Misclassification Rate for ESTIMATED Parameters:  0.43956043956043955
# Misclassification Rate for ACTUAL Parameters:  0.42657342657342656
# First Distribution Estimate:
# Prior=>  0.3
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.4
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Third Distribution Estimate:
# Prior=>  0.3
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Sample For Second Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Third Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.31092436974789917
# Mean=>  [ 0.00941947 -0.00883482]
# Cov Matrix=> [[1.02242227 0.02589133]
#  [0.02589133 1.01728573]]
# Second Distribution Estimate:
# Prior=>  0.3789515806322529
# Mean=>  [-0.00873674  1.00688723]
# Cov Matrix=> [[ 1.02386561 -0.51426291]
#  [-0.51426291  2.08635538]]
# Second Distribution Estimate:
# Prior=>  0.31012404961984796
# Mean=>  [-1.00043928  0.4894588 ]
# Cov Matrix=> [[0.78614797 0.20886349]
#  [0.20886349 0.79856107]]
# Misclassification Rate for ESTIMATED Parameters:  0.438624550179928
# Misclassification Rate for ACTUAL Parameters:  0.44582167133146744
# First Distribution Estimate:
# Prior=>  0.3
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.4
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Third Distribution Estimate:
# Prior=>  0.3
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Sample For Second Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Third Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.29745949189837967
# Mean=>  [-0.01660596 -0.02874288]
# Cov Matrix=> [[ 1.02074675 -0.00170818]
#  [-0.00170818  1.03101697]]
# Second Distribution Estimate:
# Prior=>  0.40188037607521504
# Mean=>  [-0.03517987  0.99338847]
# Cov Matrix=> [[ 1.04334395 -0.53362784]
#  [-0.53362784  2.02882209]]
# Second Distribution Estimate:
# Prior=>  0.3006601320264053
# Mean=>  [-0.97375031  0.498153  ]
# Cov Matrix=> [[0.76545616 0.20307195]
#  [0.20307195 0.82089791]]
# Misclassification Rate for ESTIMATED Parameters:  0.4259148170365927
# Misclassification Rate for ACTUAL Parameters:  0.4277144571085783
# First Distribution Estimate:
# Prior=>  0.3
# Mean=>  [0 0]
# Cov Matrix=> [[1 0]
#  [0 1]]
# Second Distribution Estimate:
# Prior=>  0.4
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Third Distribution Estimate:
# Prior=>  0.3
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Sample For First Distribution:
# [[-0.8044583   0.32093155]
#  [-0.02548288  0.64432383]
#  [-0.30079667  0.38947455]
#  [-0.1074373  -0.47998308]
#  [ 0.5950355  -0.46466753]
#  [ 0.66728131 -0.80611561]
#  [-1.19606983 -0.40596016]
#  [-0.18237734  0.10319289]
#  [-0.13842199  0.70569237]
#  [ 1.27179528 -0.98674733]]
# Sample For Second Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Third Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.3045304530453045
# Mean=>  [-0.01027486 -0.01061217]
# Cov Matrix=> [[ 1.02345229 -0.0212634 ]
#  [-0.0212634   1.04296076]]
# Second Distribution Estimate:
# Prior=>  0.40074007400740075
# Mean=>  [0.00756702 0.98451563]
# Cov Matrix=> [[ 1.05180335 -0.51512733]
#  [-0.51512733  2.00761776]]
# Second Distribution Estimate:
# Prior=>  0.29472947294729473
# Mean=>  [-0.98847332  0.49675944]
# Cov Matrix=> [[0.75988245 0.19434007]
#  [0.19434007 0.83492951]]
# Misclassification Rate for ESTIMATED Parameters:  0.43185681431856815
# Misclassification Rate for ACTUAL Parameters:  0.43215678432156784
# Misclass Rate when N=2000:  -0.012987012987012991
# Misclass Rate when N=5000:  0.007197121151539421
# Misclass Rate when N=10000:  0.001799640071985631
# Misclass Rate when N=20000:  0.00029997000299969434

# %%
#Case 7
misclass_rate_diff_n2000=BayesClassificationTHREE(2000,miu2,miu3,miu4,sigma2,sigma3,sigma4,0.2,0.7,0.1)
misclass_rate_diff_n5000=BayesClassificationTHREE(5000,miu2,miu3,miu4,sigma2,sigma3,sigma4,0.2,0.7,0.1)
misclass_rate_diff_n10000=BayesClassificationTHREE(10000,miu2,miu3,miu4,sigma2,sigma3,sigma4,0.2,0.7,0.1)
misclass_rate_diff_n20000=BayesClassificationTHREE(20000,miu2,miu3,miu4,sigma2,sigma3,sigma4,0.2,0.7,0.1)

print("Misclass Rate when N=2000: ",misclass_rate_diff_n2000)
print("Misclass Rate when N=5000: ",misclass_rate_diff_n5000)
print("Misclass Rate when N=10000: ",misclass_rate_diff_n10000)
print("Misclass Rate when N=20000: ",misclass_rate_diff_n20000)
# Out:
# First Distribution Estimate:
# Prior=>  0.2
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Second Distribution Estimate:
# Prior=>  0.7
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Third Distribution Estimate:
# Prior=>  0.1
# Mean=>  [-2.   1.3]
# Cov Matrix=> [[2.  0.8]
#  [0.8 1.6]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Third Distribution:
# [[-1.16780834  2.3518793 ]
#  [-2.35907261  1.82697523]
#  [-1.85261703  1.90308046]
#  [-1.57107991  1.03347719]
#  [-2.47740879  0.3450272 ]
#  [-2.36213446  0.0072    ]
#  [-0.2259446   2.176477  ]
#  [-1.82983337  1.56216165]
#  [-2.25215452  1.98734846]
#  [-3.02428056 -0.73611761]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.2022022022022022
# Mean=>  [0.00356625 0.88705161]
# Cov Matrix=> [[ 1.02974843 -0.43502825]
#  [-0.43502825  1.94854578]]
# Second Distribution Estimate:
# Prior=>  0.7007007007007007
# Mean=>  [-0.99069496  0.49558087]
# Cov Matrix=> [[0.76714511 0.2033962 ]
#  [0.2033962  0.77548107]]
# Second Distribution Estimate:
# Prior=>  0.0970970970970971
# Mean=>  [-1.84364555  1.42704126]
# Cov Matrix=> [[2.25969479 0.90186469]
#  [0.90186469 1.56965251]]
# Misclassification Rate for ESTIMATED Parameters:  0.23376623376623376
# Misclassification Rate for ACTUAL Parameters:  0.4755244755244755
# First Distribution Estimate:
# Prior=>  0.2
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Second Distribution Estimate:
# Prior=>  0.7
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Third Distribution Estimate:
# Prior=>  0.1
# Mean=>  [-2.   1.3]
# Cov Matrix=> [[2.  0.8]
#  [0.8 1.6]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Third Distribution:
# [[-1.16780834  2.3518793 ]
#  [-2.35907261  1.82697523]
#  [-1.85261703  1.90308046]
#  [-1.57107991  1.03347719]
#  [-2.47740879  0.3450272 ]
#  [-2.36213446  0.0072    ]
#  [-0.2259446   2.176477  ]
#  [-1.82983337  1.56216165]
#  [-2.25215452  1.98734846]
#  [-3.02428056 -0.73611761]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.21
# Mean=>  [-0.01240568  0.98778471]
# Cov Matrix=> [[ 0.97348782 -0.47801312]
#  [-0.47801312  2.02785741]]
# Second Distribution Estimate:
# Prior=>  0.6912
# Mean=>  [-0.97705199  0.48899695]
# Cov Matrix=> [[0.74604514 0.20410573]
#  [0.20410573 0.83298533]]
# Second Distribution Estimate:
# Prior=>  0.0988
# Mean=>  [-1.92498261  1.34701664]
# Cov Matrix=> [[2.04947997 0.73832334]
#  [0.73832334 1.54465956]]
# Misclassification Rate for ESTIMATED Parameters:  0.224
# Misclassification Rate for ACTUAL Parameters:  0.4808
# First Distribution Estimate:
# Prior=>  0.2
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Second Distribution Estimate:
# Prior=>  0.7
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Third Distribution Estimate:
# Prior=>  0.1
# Mean=>  [-2.   1.3]
# Cov Matrix=> [[2.  0.8]
#  [0.8 1.6]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Third Distribution:
# [[-1.16780834  2.3518793 ]
#  [-2.35907261  1.82697523]
#  [-1.85261703  1.90308046]
#  [-1.57107991  1.03347719]
#  [-2.47740879  0.3450272 ]
#  [-2.36213446  0.0072    ]
#  [-0.2259446   2.176477  ]
#  [-1.82983337  1.56216165]
#  [-2.25215452  1.98734846]
#  [-3.02428056 -0.73611761]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.20244048809761953
# Mean=>  [-0.00481004  0.99720255]
# Cov Matrix=> [[ 1.01777792 -0.52442498]
#  [-0.52442498  2.11133094]]
# Second Distribution Estimate:
# Prior=>  0.6983396679335867
# Mean=>  [-0.99263806  0.50720077]
# Cov Matrix=> [[0.76068459 0.19635205]
#  [0.19635205 0.82741648]]
# Second Distribution Estimate:
# Prior=>  0.09921984396879376
# Mean=>  [-1.96948111  1.32426394]
# Cov Matrix=> [[2.038902   0.79244292]
#  [0.79244292 1.56888984]]
# Misclassification Rate for ESTIMATED Parameters:  0.22335532893421317
# Misclassification Rate for ACTUAL Parameters:  0.4667066586682663
# First Distribution Estimate:
# Prior=>  0.2
# Mean=>  [0 1]
# Cov Matrix=> [[ 1.  -0.5]
#  [-0.5  2. ]]
# Second Distribution Estimate:
# Prior=>  0.7
# Mean=>  [-1.   0.5]
# Cov Matrix=> [[0.75 0.2 ]
#  [0.2  0.8 ]]
# Third Distribution Estimate:
# Prior=>  0.1
# Mean=>  [-2.   1.3]
# Cov Matrix=> [[2.  0.8]
#  [0.8 1.6]]
# Sample For First Distribution:
# [[ 0.72137547  0.00520393]
#  [ 0.54454998  1.18458255]
#  [ 0.49141797  0.71985949]
#  [-0.33378394  0.68897889]
#  [-0.72055936  1.65837428]
#  [-1.04253025  1.64118358]
#  [ 0.3460294  -0.77999576]
#  [ 0.18857962  0.78484253]
#  [ 0.65924467  1.05048025]
#  [-1.53481224  2.40935518]]
# Sample For Second Distribution:
# [[-0.65607842  1.25681077]
#  [-1.34911796  0.84178608]
#  [-1.02438463  0.91802965]
#  [-0.65724889  0.33904682]
#  [-1.1253601  -0.17369658]
#  [-0.97876813 -0.39833815]
#  [ 0.01269282  1.18264481]
#  [-0.93930817  0.68682799]
#  [-1.31009492  0.956211  ]
#  [-1.27157476 -0.93671021]]
# Sample For Third Distribution:
# [[-1.16780834  2.3518793 ]
#  [-2.35907261  1.82697523]
#  [-1.85261703  1.90308046]
#  [-1.57107991  1.03347719]
#  [-2.47740879  0.3450272 ]
#  [-2.36213446  0.0072    ]
#  [-0.2259446   2.176477  ]
#  [-1.82983337  1.56216165]
#  [-2.25215452  1.98734846]
#  [-3.02428056 -0.73611761]]
# Training Data Geerated
# First Distribution Estimate:
# Prior=>  0.2005200520052005
# Mean=>  [-0.03559795  0.99505842]
# Cov Matrix=> [[ 1.04419397 -0.53154479]
#  [-0.53154479  2.02290858]]
# Second Distribution Estimate:
# Prior=>  0.7028702870287029
# Mean=>  [-0.98471273  0.50796681]
# Cov Matrix=> [[0.74694179 0.19004883]
#  [0.19004883 0.82353883]]
# Second Distribution Estimate:
# Prior=>  0.0966096609660966
# Mean=>  [-2.00296434  1.2970613 ]
# Cov Matrix=> [[2.07695743 0.83686738]
#  [0.83686738 1.64595421]]
# Misclassification Rate for ESTIMATED Parameters:  0.21827817218278173
# Misclassification Rate for ACTUAL Parameters:  0.46395360463953605
# Misclass Rate when N=2000:  0.24175824175824176
# Misclass Rate when N=5000:  0.25680000000000003
# Misclass Rate when N=10000:  0.24335132973405316
# Misclass Rate when N=20000:  0.24567543245675433
